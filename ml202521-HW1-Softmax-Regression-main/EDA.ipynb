# %% [markdown]
# ## Exploratory Data Analysis
# Вы можете использовать этот ноутбук, чтобы покапаться в данных и нагенерить идей для фича инжиниринга. Этот ноутбук не обязателен к использованию и загружать никуда не требуется.

# %%
import matplotlib.pyplot as plt
import numpy as np

from solution import *
from datasets import load_dataset

trainset = load_dataset("phystech/logreg_train", token=None, split='train')
X_train, y_train = np.stack([x['data'] for x in trainset]), np.stack([x['label'] for x in trainset])
# Out:
# README.md:   0%|          | 0.00/308 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/103k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]
